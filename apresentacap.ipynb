# %% [markdown]
# <a href="https://colab.research.google.com/github/hygo2025/cdd-projeto-final/blob/main/apresentacap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📌 O que são Sistemas de Recomendação?
#
# - **Definição**:
#   Sistemas de Recomendação (Recommender Systems, RS) são sistemas de filtragem de informações que têm como função **prever e sugerir itens** que um usuário possivelmente vai gostar [1].
#
# - **Tipos de itens recomendados**:
#   - Produtos (e-commerce)
#   - Filmes e séries
#   - Músicas e playlists
#   - Artigos e notícias
#
# - **Base das recomendações**:
#   - Comportamento passado do próprio usuário
#   - Preferências explícitas (ex: avaliações)
#   - Comportamento de usuários semelhantes
#
# - **Objetivos principais**:
#   - Melhorar a **experiência do usuário**
#   - Aumentar o **engajamento** com a plataforma
#   - Ajudar na **tomada de decisão** em meio ao excesso de opções [2]
#
# - **Domínios de aplicação**:
#   - E-commerce
#   - Entretenimento (streaming)
#   - Mídias sociais
#   - Educação e serviços personalizados
#
# - **Importância**:
#   - Relevantes tanto na **pesquisa acadêmica** (teoria e modelos)
#   - Quanto em **aplicações reais** na indústria (negócios e tecnologia)

# %% [markdown]
# ## Como funciona uma recomendação?
#
# Por trás de uma recomendação existe um algoritmo que **aprende padrões** a partir de dados de usuários, itens e interações entre eles.
#
# Existem três abordagens principais:
#
# - **Filtragem colaborativa (CF)** \[20\] baseia-se na ideia de que usuários com preferências semelhantes provavelmente terão gostos semelhantes no futuro. A CF recomenda itens encontrando um "vizinhança" de usuários ou itens semelhantes. Apesar de não precisar de muita análise de conteúdo, ela enfrenta desafios como o problema de *cold start*, escalabilidade e esparsidade \[34\].
#
# - **Filtragem baseada em conteúdo (CBF)** \[72\] recomenda itens com base nas preferências do usuário e nas características dos itens, utilizando técnicas como **TF-IDF** (*Term Frequency - Inverse Document Frequency*), similaridade cosseno e redes neurais para representação de itens. No entanto, pode ter dificuldades em recomendar itens novos ou inéditos.
#
# - **RS híbridos** \[36\] combinam as forças de ambas as abordagens, oferecendo recomendações mais precisas e personalizadas por meio da integração de metodologias diversas.

# %% [markdown]
# ### Um pouco da Matemática por trás
#
# Um sistema de recomendação (*RS*) pode ser matematicamente representado como uma função $f$ que prediz a utilidade de um item $i$ para um usuário $u$, denotada como $\hat{r}_{ui}$, que estima o quanto o usuário $u$ preferiria o item $i$ \[3\]. Esta função é geralmente aprendida a partir de dados históricos:
#
# $$
# \hat{r}_{ui} = f(u, i; \Theta)
# $$
#
# Onde:
#
# - $\Theta$ representa os parâmetros do modelo, aprendidos a partir dos dados.
#
# No contexto dos RS, o termo $\hat{r}_{ui}$ representa uma previsão da classificação ou utilidade que um usuário atribuiria a um item. Essa previsão é usada para recomendar itens que provavelmente sejam do interesse do usuário.

# %% [markdown]
# ### Como funcionar o processo de uma recomendação:

# %% [markdown]
# ![54261768aaadc1ea82b0d8be90e64e01.png](data:image/png;base64,...)

# %% [markdown]
# Uma estrutura geral de sistemas de recomendação (*RS*) é ilustrada na **Figura 2**. O ciclo de vida de um modelo orientado por dados dentro de um RS começa com:
#
# 1.  **Aquisição de dados**, seguida por **armazenamento** e **preparação**.
# 2.  Isso leva à **engenharia de características**, formando a base do pipeline de dados.
# 3.  O pipeline de dados alimenta o pipeline de treinamento, que inclui:
#     - Treinamento do modelo.
#     - Validação.
#
# Após o treinamento, o processo envolve:
#
# - **Geração de candidatos**.
# - **Ranqueamento**.
#
# Esse processo é complementado por:
#
# - **Testes A/B**.
# - Avaliação offline e/ou online.
#
# As etapas finais incluem **implantação** e **monitoramento**.

# %% [markdown]
# ### Content-Based Filtering
#
# A filtragem baseada em conteúdo (*Content-Based Filtering*, CBF) é uma estratégia de recomendação que sugere itens a um usuário com base nos atributos dos itens e em um perfil das preferências do usuário, normalmente utilizando medidas de similaridade para combinar as preferências do usuário com os atributos do item \[83\].
#
# Na CBF, a recomendação $\hat{r}_{ui}$ é baseada nas características dos itens $\phi(i)$ e no perfil das preferências do usuário $\theta(u)$:
#
# $$
# \hat{r}_{ui} = \theta(u)^\top \phi(i)
# $$
#
# (2)
#
# - $\phi(i)$ representa o vetor de características do item.
# - $\theta(u)$ representa o vetor de preferências do usuário.
#
# * * *
#
# A evolução dos modelos de recomendação baseados em conteúdo começa com métodos tradicionais \[83\], como:
#
# - **Modelos de espaço vetorial**,
# - **Modelos probabilísticos**,
# - **Árvores de decisão**,
#
# Esses métodos contam com engenharia manual de características e cálculos de similaridade. Por exemplo:
#
# - **Modelos de espaço vetorial** computam similaridade entre itens por meio de **similaridade cosseno** \[84\].
# - **Modelos probabilísticos** estimam a probabilidade de preferência do usuário com análise estatística \[85\].
# - **Árvores de decisão** recomendam itens categorizando-os com base nos atributos \[83\].
#
# Esses modelos estabeleceram as bases para recomendações personalizadas ao alavancar explicitamente características dos itens e preferências dos usuários.
#
# * * *
#
# Os avanços algorítmicos em ciência da computação e métodos de aprendizado de máquina levaram a uma mudança para redes neurais sofisticadas que permitem:
#
# - Extração automática de características.
# - Aprendizado de padrões complexos de dados \[86\].
#
# Esses sistemas baseados em redes neurais aproveitam aprendizado profundo para analisar interações dos usuários e características dos itens em diferentes modalidades, incluindo:
#
# - **Textuais** (como revisões \[87\], citações \[88\] e notícias \[89\]),
# - **Streaming** (como música \[77\]),
# - **Dados de imagem** \[90\].
#
# O objetivo geral desses avanços é gerar recomendações personalizadas alinhando perfis de usuários com características dos itens.
#
# * * *
#
# **Desafios da CBF**: De modo geral, a CBF enfrenta desafios como:
#
# - O problema de *cold start*,
# - **Superespecialização** (recomendando apenas itens semelhantes aos que o usuário já viu ou gostou),
# - **Custo computacional** (que pode crescer quadraticamente com o número de usuários e itens),
# - **Falta de atualizações** nos perfis de usuários e itens.

# %% [markdown]
# ### Collaborative Filtering
#
# A filtragem colaborativa (*Collaborative Filtering*, CF) é uma técnica usada por RS para prever as preferências de um usuário com base nas preferências de outros usuários semelhantes \[34\].
#
# As técnicas de CF são amplamente divididas em duas categorias principais:
#
# 1.  **Métodos baseados em memória**:
#
#     - Recomendam itens com base em similaridades entre usuários ou itens diretamente das classificações dos usuários.
#     - Exemplos incluem:
#         - CF baseada no usuário (prediz classificações com base no histórico de classificações de usuários semelhantes) \[70\].
#         - CF baseada no item (prediz classificações com base em itens semelhantes) \[91\].
# 2.  **Métodos baseados em modelo**:
#
#     - CF baseados em modelo, como **fatoração de matriz** \[92\] e **máquinas de fatoração** \[93\], descobrem fatores latentes que representam preferências de usuários e características de itens.
#
# Esses métodos decompõem a matriz de interação usuário-item em vetores de características latentes para usuários e itens.
#
# * * *
#
# Ambos os métodos enfrentam desafios, como:
#
# - Escalabilidade,
# - Esparsidade.
#
# A CF frequentemente começa com a construção de uma matriz de interação usuário-item $R$ com usuários, itens e $r_{ui}$ representando interações conhecidas entre usuários e itens. Uma abordagem popular dentro da CF é a **fatoração de matriz** \[92\], onde $R$ é aproximada pelo produto de duas matrizes de menor dimensão, $U$ (características do usuário) e $I$ (características do item):
#
# $$
# \hat{R} = U^\top I
# $$
#
# (3)
#
# - $U$ é uma matriz $k \times m$, com $k$ sendo o número de fatores latentes e $m$ o número de usuários.
# - $I$ é uma matriz $k \times n$, com $n$ sendo o número de itens.
#
# * * *
#
# As extensões neurais na CF têm aprimorado esses sistemas, utilizando aprendizado profundo para capturar relações complexas entre usuários e itens, melhorando significativamente a precisão das recomendações. Técnicas como:
#
# - **Filtragem Colaborativa Neural (NCF)** \[94\],
# - **Sistemas de Recomendação Ciente de Sequência (Sequence-Aware RS)** \[95\],
# - **Redes Neurais em Grafos (GNNs)** \[48\],
#
# emergiram como abordagens de ponta na CF.
#
# * * *
#
# **Desafios da CF**: Assim como a CBF, esses métodos são mais precisos e robustos. No entanto, eles também apresentam desafios, como:
#
# - **Complexidade computacional**,
# - **Baixa interpretabilidade**, o que pode limitar sua escalabilidade e aplicabilidade prática em cenários do mundo real.

# %% [markdown]
# ### Hybrid Approaches
#
# Um RS híbrido combina múltiplas técnicas de recomendação, como CBF, CF e outros modelos de aprendizado de máquina, para melhorar a precisão e a relevância das recomendações fornecidas aos usuários.
#
# As técnicas híbridas mais comuns incluem:
#
# - **Combinação ponderada**,
# - **Seleção alternada**,
# - **Combinação de características**,
# - **Cascata**,
# - **Aumento de características** \[96\].
#
# A combinação pode ser representada como uma soma ponderada:
#
# $$
# \hat{r}_{ui} = \alpha \cdot f_{CB}(u, i; \Theta_{CB}) + \beta \cdot f_{CF}(u, i; \Theta_{CF})
# $$
#
# (4)
#
# - $f_{CB}$ e $f_{CF}$ representam as funções de filtragem baseada em conteúdo e colaborativa, respectivamente.
# - $\Theta_{CB}$ e $\Theta_{CF}$ são os parâmetros para cada modelo respectivo.
# - $\alpha$ e $\beta$ são os pesos que equilibram a contribuição de cada método.
#
# * * *
#
# Técnicas como:
#
# - **Wide & Deep Learning Framework** \[97\],
# - **Máquinas de Fatoração Neural (NFM)** \[98\],
# - **DeepFM** \[99\],
# - **Deep & Cross Network** \[100\],
#
# combinam interações explícitas de características e hierarquias implícitas de características, alavancando modelos de aprendizado raso e profundo para recomendações aprimoradas.

# %% [markdown]
# ![5896f7e2e679a1012037ffee36250384.png](data:image/png;base64,...)

# %% [markdown]
# ### Experimento

# %% [markdown]
# O trabalho tem como foco a comparação de algortimos de recomendação com base em filtragem colaborativa, Passando por algoritmos baseados em similaridade, fatoração de matrizes, deep learning, modelos generativos e redes neurais. Por meio das métricas Precision, Recall, MAP e NDCG.

# %% [markdown]
# ### Base de dados utilizada
#
# Os dados utilizados para a construção das avaliações são do MovieLens. Esse dataset é composto por avaliações de filmes feitas por usuários. Especificamente, utilizamos a versão MovieLens 1M, que contém 1.000.209 avaliações feitas por 6.040 usuários em 3.883 filmes distintos.

# %% [markdown]
# ## 🧪 Metodologia
#
# ### 🔧 Algoritmos Utilizados
#
# - **SAR**: Algoritmo adaptativo, rápido e escalável para recomendações personalizadas baseado no histórico de transações do usuário e descrição dos itens. Produz recomendações interpretáveis e lida bem com *cold items* e *semi-cold users* [@microsoftSAR].
#
# - **ALS (Alternating Least Squares)**: Técnica de fatoração de matrizes que alterna o ajuste dos vetores de usuários e itens, minimizando o erro de predição em grandes volumes de dados [@he2017fastmatrixfactorizationonline].
#
# - **NCF (Neural Collaborative Filtering)**: Utiliza redes neurais para aprender representações latentes de usuários e itens, capturando relações não lineares mais complexas do que abordagens tradicionais [@he2017neuralcollaborativefiltering].
#
# - **BiVAE (Bilateral Variational Autoencoder)**: Emprega autoencoders variacionais bilaterais para gerar representações latentes de usuários e itens, proporcionando melhores recomendações em diferentes contextos [@truong2021bilateral].
#
# - **LightGCN**: Algoritmo baseado em grafos que simplifica redes neurais para modelar relações entre usuários e itens, melhorando o desempenho em tarefas de recomendação [@he2020lightgcnsimplifyingpoweringgraph].
#
# - **FastAI**: Framework de aprendizado profundo que fornece ferramentas flexíveis e de alta performance para construir modelos de recomendação [@Howard_2020].
#
# ---
#
# ### ⚙️ Metodologia dos Testes
#
# O mesmo processo foi aplicado para todos os algoritmos, com as seguintes etapas:
#
# - Divisão entre treino e teste: 75% dos dados foram utilizados para treino e 25% para teste.
# - Treinamento do modelo.
# - Avaliação do modelo.
#
# ---
#
# ### 📏 Metodologia de Avaliação
#
# As métricas utilizadas neste trabalho foram:
#
# - Precision
# - Recall
# - MAP (Mean Average Precision)
# - NDCG (Normalized Discounted Cumulative Gain)
#
# Essas métricas foram calculadas sobre os dados de teste com o suporte das ferramentas fornecidas pelo MS Recommenders da Microsoft [@microsoft_recommenders:20]. A base de dados utilizada foi a **MovieLens-1M**.
#
# Itens e usuários exclusivos do conjunto de teste foram removidos. As predições e os conjuntos de teste foram mantidos fixos para garantir a reprodutibilidade dos resultados.
#
# ---
#
# ### 🎯 Precision
#
# A precisão (Precision@k) mede a proporção de itens recomendados que são realmente relevantes:
#
# $$
# \text{Precision@k} = \frac{|\{ \text{Itens Relevantes} \} \cap \{ \text{Itens Recomendados}@k \}|}{|\{ \text{Itens Recomendados}@k \}|}
# $$
#
# ---
#
# ### 🎯 Recall
#
# O Recall@k mede a proporção dos itens relevantes que foram recuperados:
#
# $$
# \text{Recall@k} = \frac{|\{ \text{Itens Relevantes} \} \cap \{ \text{Itens Recomendados}@k \}|}{|\{ \text{Itens Relevantes} \}|}
# $$
#
# ---
#
# ### 📊 Mean Average Precision (MAP)
#
# A média da precisão acumulada por posição de cada item relevante:
#
# $$
# \text{AP@k} = \frac{1}{|\{ \text{Itens Relevantes} \}|} \sum_{i=1}^{k} \text{Precision@i} \cdot \mathbb{1}(\text{relevante}_i)
# $$
#
# $$
# \text{MAP@k} = \frac{1}{|U|} \sum_{u \in U} \text{AP@k}_u
# $$
#
# ---
#
# ### 📈 Normalized Discounted Cumulative Gain (NDCG)
#
# Mede a relevância dos itens considerando suas posições na lista recomendada:
#
# $$
# \text{DCG@k} = \sum_{i=1}^{k} \frac{\text{rel}_i}{\log_2(i+1)}
# $$
#
# $$
# \text{IDCG@k} = \sum_{i=1}^{k} \frac{\text{rel}^*_i}{\log_2(i+1)}
# $$
#
# $$
# \text{NDCG@k} = \frac{\text{DCG@k}}{\text{IDCG@k}}
# $$
#
# ---
#
# ### 💻 Experimentos
#
# Todos os experimentos foram realizados no **Google Colab**, com os seguintes recursos:
#
# - **GPU**: NVIDIA L4 com 24 GB de VRAM GDDR6
#   - 7.424 núcleos CUDA
#   - 232 núcleos Tensor (4ª geração)
# - **CPU**: Intel Xeon @ 2.20GHz (12 núcleos físicos)
# - **RAM**: 53 GB
# - **SO**: Ubuntu 22.04.4 LTS
#
# A escolha de hiperparâmetros foi feita via **grid search**, com base nos valores reportados na literatura.

# %% [markdown]
# ### Resultados
#
# ### 📊 Melhores versões por algoritmo (Ordenadas por nDCG@K)
#
# | **Algorithm** | **MAP**     | **nDCG@K** | **Precision@K** | **Recall@K** |
# |---------------|-------------|------------|------------------|--------------|
# | bivae         | 0.278428    | 0.410565   | 0.376242         | 0.136264     |
# | lightgcn      | 0.230407    | 0.359210   | 0.319371         | 0.144064     |
# | sar           | 0.219533    | 0.345610   | 0.307864         | 0.114765     |
# | fastai        | 0.103932    | 0.190846   | 0.173675         | 0.056479     |
# | ncf           | 0.079693    | 0.154868   | 0.144586         | 0.055151     |
# | als           | 0.043372    | 0.096373   | 0.091623         | 0.027791     |

# %% [markdown]
# ![resultados_por_algoritmo.png](data:image/png;base64,...)
